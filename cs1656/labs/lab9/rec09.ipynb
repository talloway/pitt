# %% [markdown]
# # CS 1656 – Introduction to Data Science
#
# ## Instructor: Alexandros Labrinidis / Teaching Assistant: Evangelos Karageorgos
# ### Additional credits: Xiaoting Li, Phuong Pham, Zuha Agha, Anatoli Shein
# ## Recitation 9: Collaborative Filtering & Similarity Metrics
# ---
# In this recitation we will be doing a fun exercise to implement collaborative filtering for recommender systems. We will also learn how the choice of similarity metric in collaborative filtering can affect its output of predicted ratings.
#
# Packages you will need for the recitation are,
#
# * pandas
# * numpy
# * scipy
#
# Recall that numpy package provides nd-arrays and operations for easily manipulating them.
# Likewise, scipy provides an addtional suite of useful mathematical functions and distributions for numpy arrays, including distance functions which we will use in this recitation to compute the measure of similarity. We will only import the distance funcions we need for today's session as shown below. Note that cityblock is just another name for Manhattan distance metric seen in class.

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import euclidean, cityblock, cosine
from scipy.stats import pearsonr

# %% [markdown]
# ## User-Based vs Item-Based Recommendation
# There are two type of collaborative filtering method: user-based and item-based.
#
# User-based recommendation assumes that similar users give similar ratings to each item. Whereas item-based recommendation assumes that similar items receive similar ratings from each user. You can think of them as a dual of each other.
#
# In this recitation, we will walk through a toy example for user-based recommendation and you will try out item-based recommendation later in one of your tasks.
#
# ## Data Input

# %%
df = pd.read_csv('http://data.cs1656.org/movies_example.csv')
df
# Out:
#                  Name  Alice  Bob  Christine  David  Elaine  Frank
# 0          The Matrix      2  3.0          4    5.0     5.0    NaN
# 1  Gone with the Wind      5  NaN          5    NaN     3.0    3.0
# 2       Jack and Jill      2  1.0          2    2.0     1.0    1.0
# 3              Planes      4  4.0          5    2.0     NaN    3.0
# 4            Rocky IV      2  2.0          3    4.0     3.0    NaN

# %% [markdown]
# ### Accessing rows in dataframe

# %% [markdown]
# The two ways to access dataframes rows are shown below,

# %%
# Converting value equality test fo a Series of booleans
df['Name'] == 'The Matrix'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
# First way to access rows
df[df['Name'] == 'The Matrix']
# Out:
#          Name  Alice  Bob  Christine  David  Elaine  Frank
# 0  The Matrix      2  3.0          4    5.0     5.0    NaN

# %%
# Second way
df.iloc[0]
# Out:
# Name         The Matrix
# Alice                 2
# Bob                   3
# Christine             4
# David                 5
# Elaine                5
# Frank               NaN
# Name: 0, dtype: object

# %% [markdown]
# ### Missing values in data frame

# %% [markdown]
# To exlude missing values or NaNs in a dataframe, we can use the notnull() function.

# %%
df['Frank'].notnull()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Frank, dtype: bool

# %%
df['Elaine'].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Elaine, dtype: bool

# %% [markdown]
# You can also perform logical operations on the boolean Series returned as shown below,

# %%
df['Frank'].notnull() & df['Elaine'].notnull()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# You can also select subset of rows and columns where the boolean value is True.

# %%
df_notmissing = df[['Frank','Elaine']][df['Frank'].notnull() & df['Elaine'].notnull()]
df_notmissing
# Out:
#    Frank  Elaine
# 1    3.0     3.0
# 2    1.0     1.0

# %% [markdown]
# ## Similarity Metrics & Predicted Ratings
# Different distance metrics can be used to measure the similarity. In this recitation, we will use Euclidean, Manhattan, Pearson Correlation and Cosine distance metrics to measure the similarity.
#
# ### Euclidean

# %%
sim_weights = {}
for user in df.columns[1:-1]:
    df_subset = df[['Frank',user]][df['Frank'].notnull() & df[user].notnull()]
    dist = euclidean(df_subset['Frank'], df_subset[user])
    sim_weights[user] = 1.0 / (1.0 + dist)
print ("similarity weights: %s" % sim_weights)
# Out:
# similarity weights: {'Alice': 0.28989794855663564, 'Bob': 0.5, 'Christine': 0.25, 'David': 0.4142135623730951, 'Elaine': 1.0}

# %% [markdown]
# Now let's find the predicted rating of 'Frank' for 'The Matrix'. We can get all ratings for a movie by accessing a row of the dataframe using iloc learnt earlier. We only slice the columns of ratings we need indicated by the index [1:-1]. In this case we do not need the first column 'Name' and the last column 'Frank'.

# %%
ratings = df.iloc[0][1:-1]
ratings
# Out:
# Alice        2
# Bob          3
# Christine    4
# David        5
# Elaine       5
# Name: 0, dtype: object

# %% [markdown]
# Now we will find our predicted rating by multiplying each user weight with its corresponding rating for the movie matrix.

# %%
predicted_rating = 0.0
weights_sum = 0.0
for user in df.columns[1:-1]:
    predicted_rating += ratings[user] * sim_weights[user]
    weights_sum += sim_weights[user]

predicted_rating /= weights_sum
print ("predicted rating: %f" % predicted_rating)
# Out:
# predicted rating: 4.136268

# %% [markdown]
# ### Manhattan (Cityblock)

# %% [markdown]
# We repeat our method of finding predicted rating using cityblock distance now.

# %%
sim_weights = {}
for user in df.columns[1:-1]:
    df_subset = df[['Frank',user]][df['Frank'].notnull() & df[user].notnull()]
    dist = cityblock(df_subset['Frank'], df_subset[user])
    sim_weights[user] = 1.0 / (1.0 + dist)
print ("similarity weights: %s" % sim_weights)

predicted_rating = 0
weights_sum = 0.0
ratings = df.iloc[0][1:-1]
for user in df.columns[1:-1]:
    predicted_rating += ratings[user] * sim_weights[user]
    weights_sum += sim_weights[user]

predicted_rating /= weights_sum
print ("predicted rating: %f" % predicted_rating)
# Out:
# similarity weights: {'Alice': 0.2, 'Bob': 0.5, 'Christine': 0.16666666666666666, 'David': 0.3333333333333333, 'Elaine': 1.0}
# predicted rating: 4.196970

# %% [markdown]
# ### Pearson Correlation Coefficient

# %%
sim_weights = {}
for user in df.columns[1:-1]:
    df_subset = df[['Frank',user]][df['Frank'].notnull() & df[user].notnull()]
    sim_weights[user] = pearsonr(df_subset['Frank'], df_subset[user])[0]
print ("similarity weights: %s" % sim_weights)

predicted_rating = 0.0
weights_sum = 0.0
ratings = df.iloc[0][1:-1]
for user in df.columns[1:-1]:
    predicted_rating += ratings[user] * sim_weights[user]
    weights_sum += sim_weights[user]

predicted_rating /= weights_sum
print ("predicted rating: %s" % predicted_rating)
# Out:
# similarity weights: {'Alice': 0.9449111825230679, 'Bob': 1.0, 'Christine': 1.0, 'David': nan, 'Elaine': 1.0}
# predicted rating: nan
# C:\Users\Avery Peiffer\anaconda3_new\lib\site-packages\scipy\stats\stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %% [markdown]
# Why nan?
# Because anything divided by 0 is undefined. Computing it again with this modfication gives the following.

# %%
predicted_rating = 0.0
weights_sum = 0.0
ratings = df.iloc[0][1:-1]
for user in df.columns[1:-1]:
    if (not np.isnan(sim_weights[user])):
        predicted_rating += ratings[user] * sim_weights[user]
        weights_sum += sim_weights[user]

predicted_rating /= weights_sum
print ("predicted rating: %f" % predicted_rating)
# Out:
# predicted rating: 3.520947

# %% [markdown]
# ## Tasks
# For your tasks, use the movie ratings data we collected from a previous class in movie_class_responses.csv. You will predict missing movie ratings of a student based on other students with similar tastes. The first column, 'Alias' is the name of the movie, while all other columns are user names of students. The ratings are from 1 to 5, while there are a lot of missing values (missing movie ratings).

# %%
df = pd.read_csv('http://data.cs1656.org/movie_class_responses.csv')
df.head()
# Out:
#                    Alias  potatofaminewasaninsidejob  Thug Nugget  \
# 0      50 Shades of Grey                         1.0          NaN
# 1               Airplane                         NaN          NaN
# 2  Au Revoir Les Enfants                         NaN          NaN
# 3         Blues Brothers                         NaN          NaN
# 4             Dark Night                         NaN          3.0
#
#    Arjen_Robben_Is_Cool  Oh-Long Johnson  BigD  Starlord  captainamerica  \
# 0                   NaN              1.0   NaN       1.0             1.0
# 1                   NaN              5.0   NaN       3.0             NaN
# 2                   NaN              2.0   NaN       NaN             NaN
# 3                   NaN              4.0   NaN       NaN             NaN
# 4                   NaN              5.0   5.0       5.0             NaN
#
#    BabyKangaroo  Ryan  ...  Garbage   CleverAlias  Kirito  ryan  \
# 0           NaN     1  ...         3            3     1.0     1
# 1           4.0     4  ...         5            3     5.0     1
# 2           NaN     3  ...         3            3     NaN     3
# 3           2.0     3  ...         5            3     4.0     3
# 4           5.0     5  ...         4            3     4.0     4
#
#    Geek in the Pink  Michelle  Jim Jarmush  rater  RonJohnson  Dory
# 0                 1       NaN          1.0    NaN           2   2.0
# 1                 3       NaN          NaN    NaN           4   NaN
# 2                 3       NaN          NaN    NaN           4   NaN
# 3                 4       NaN          4.0    NaN           4   NaN
# 4                 4       NaN          NaN    4.0           5   5.0
#
# [5 rows x 32 columns]

# %%
df
# Out:
#                                     Alias  potatofaminewasaninsidejob  \
# 0                       50 Shades of Grey                         1.0
# 1                                Airplane                         NaN
# 2                   Au Revoir Les Enfants                         NaN
# 3                          Blues Brothers                         NaN
# 4                              Dark Night                         NaN
# 5                         Deadpool (2016)                         4.0
# 6               Don't Mess with the Zohan                         NaN
# 7                             Dr. Strange                         4.0
# 8                              Ex Machina                         4.0
# 9                        Fast and Furious                         NaN
# 10                             Fight Club                         4.0
# 11                           Finding Dory                         3.0
# 12                      Good Will Hunting                         NaN
# 13                               Grownups                         2.0
# 14     Harry Potter: The Sorcerer's Stone                         3.0
# 15                          Jurassic Park                         3.0
# 16                                  Keanu                         NaN
# 17                             La La Land                         NaN
# 18  Lord of the Rings: Return of the King                         5.0
# 19                              Mr. Deeds                         NaN
# 20                            Nacho Libre                         NaN
# 21                    Pulp Fiction (1994)                         4.0
# 22                             Ratatuille                         3.0
# 23                    Remember the Titans                         NaN
# 24                       Sharknado (2013)                         NaN
# 25                   Shawshank Redemption                         NaN
# 26                                  Shrek                         4.0
# 27                      Snakes on a Plane                         4.0
# 28                              Spiderman                         3.0
# 29                   Star Wars: Episode I                         3.0
# 30                  Star Wars: Episode IV                         5.0
# 31      Star Wars: The Return of the Jedi                         5.0
# 32                          Step Brothers                         1.0
# 33                          Suicide Squad                         2.0
# 34                               Superbad                         NaN
# 35                           Terminator 2                         4.0
# 36                      The Fifth Element                         NaN
# 37             The Fundamentals of Caring                         NaN
# 38                          The Godfather                         NaN
# 39                     The Imitation Game                         4.0
# 40                            The Martian                         4.0
# 41                             The Matrix                         5.0
# 42                               The Room                         3.0
# 43                           Split (2016)                         NaN
# 44                              Toy Story                         NaN
# 45                               War Dogs                         NaN
#
#     Thug Nugget  Arjen_Robben_Is_Cool  Oh-Long Johnson  BigD  Starlord  \
# 0           NaN                   NaN              1.0   NaN       1.0
# 1           NaN                   NaN              5.0   NaN       3.0
# 2           NaN                   NaN              2.0   NaN       NaN
# 3           NaN                   NaN              4.0   NaN       NaN
# 4           3.0                   NaN              5.0   5.0       5.0
# 5           4.0                   NaN              5.0   NaN       2.0
# 6           NaN                   3.0              5.0   NaN       2.0
# 7           NaN                   NaN              3.0   NaN       4.0
# 8           NaN                   NaN              2.0   NaN       4.0
# 9           NaN                   NaN              1.0   4.0       1.0
# 10          2.0                   NaN              4.0   NaN       5.0
# 11          4.0                   NaN              4.0   4.0       3.0
# 12          NaN                   NaN              4.0   4.0       5.0
# 13          4.0                   NaN              1.0   NaN       1.0
# 14          4.0                   4.0              3.0   4.0       3.0
# 15          4.0                   NaN              2.0   NaN       4.0
# 16          NaN                   NaN              3.0   NaN       NaN
# 17          NaN                   NaN              2.0   NaN       NaN
# 18          5.0                   5.0              5.0   NaN       5.0
# 19          NaN                   NaN              3.0   NaN       3.0
# 20          NaN                   NaN              5.0   NaN       NaN
# 21          1.0                   NaN              5.0   5.0       4.0
# 22          2.0                   4.0              2.0   5.0       4.0
# 23          NaN                   NaN              2.0   NaN       NaN
# 24          NaN                   NaN              1.0   NaN       1.0
# 25          NaN                   NaN              5.0   NaN       4.0
# 26          2.0                   5.0              5.0   3.0       3.0
# 27          1.0                   NaN              2.0   2.0       2.0
# 28          5.0                   4.0              2.0   5.0       2.0
# 29          5.0                   3.0              2.0   NaN       1.0
# 30          5.0                   4.0              4.0   NaN       5.0
# 31          5.0                   5.0              4.0   NaN       5.0
# 32          NaN                   NaN              4.0   NaN       4.0
# 33          NaN                   NaN              2.0   2.0       3.0
# 34          5.0                   NaN              4.0   NaN       4.0
# 35          NaN                   NaN              4.0   4.0       4.0
# 36          NaN                   NaN              NaN   NaN       5.0
# 37          NaN                   NaN              NaN   NaN       NaN
# 38          1.0                   NaN              5.0   NaN       NaN
# 39          NaN                   NaN              4.0   5.0       5.0
# 40          4.0                   NaN              4.0   4.0       4.0
# 41          4.0                   5.0              4.0   NaN       5.0
# 42          NaN                   NaN              1.0   NaN       NaN
# 43          NaN                   NaN              NaN   NaN       NaN
# 44          NaN                   NaN              NaN   5.0       4.0
# 45          NaN                   NaN              NaN   NaN       3.0
#
#     captainamerica  BabyKangaroo  Ryan  ...  Garbage   CleverAlias  Kirito  \
# 0              1.0           NaN     1  ...         3            3     1.0
# 1              NaN           4.0     4  ...         5            3     5.0
# 2              NaN           NaN     3  ...         3            3     NaN
# 3              NaN           2.0     3  ...         5            3     4.0
# 4              NaN           5.0     5  ...         4            3     4.0
# 5              5.0           NaN     4  ...         5            4     4.0
# 6              NaN           NaN     2  ...         1            3     3.0
# 7              5.0           NaN     4  ...         3            5     4.0
# 8              NaN           NaN     5  ...         4            3     4.0
# 9              3.0           NaN     2  ...         3            5     4.0
# 10             4.0           5.0     4  ...         4            3     4.0
# 11             4.0           NaN     4  ...         4            5     4.0
# 12             4.0           4.0     4  ...         4            3     4.0
# 13             2.0           NaN     1  ...         3            3     NaN
# 14             4.0           NaN     3  ...         5            4     4.0
# 15             4.0           NaN     4  ...         5            4     4.0
# 16             NaN           NaN     3  ...         3            3     5.0
# 17             5.0           NaN     4  ...         1            3     4.0
# 18             3.0           NaN     5  ...         5            5     5.0
# 19             NaN           NaN     3  ...         5            3     NaN
# 20             NaN           NaN     2  ...         2            3     4.0
# 21             NaN           5.0     5  ...         5            4     4.0
# 22             4.0           4.0     4  ...         5            5     4.0
# 23             NaN           NaN     3  ...         3            3     4.0
# 24             1.0           1.0     1  ...         3            3     1.0
# 25             5.0           5.0     5  ...         4            3     NaN
# 26             5.0           NaN     5  ...         5            5     4.0
# 27             NaN           NaN     1  ...         2            3     4.0
# 28             NaN           NaN     4  ...         5            4     3.0
# 29             4.0           1.0     3  ...         4            5     3.0
# 30             4.0           NaN     5  ...         3            5     4.0
# 31             4.0           NaN     5  ...         3            5     5.0
# 32             3.0           5.0     4  ...         5            3     NaN
# 33             2.0           NaN     2  ...         3            3     2.0
# 34             4.0           NaN     5  ...         3            3     4.0
# 35             NaN           4.0     3  ...         3            4     NaN
# 36             NaN           NaN     3  ...         4            3     NaN
# 37             NaN           NaN     4  ...         1            5     NaN
# 38             4.0           5.0     5  ...         5            3     4.0
# 39             5.0           3.0     5  ...         5            3     NaN
# 40             NaN           4.0     4  ...         4            5     4.0
# 41             NaN           3.0     5  ...         4            5     4.0
# 42             NaN           NaN     3  ...         5            5     1.0
# 43             NaN           NaN     3  ...         4            3     NaN
# 44             4.0           5.0     5  ...         5            5     4.0
# 45             NaN           NaN     3  ...         3            2     NaN
#
#     ryan  Geek in the Pink  Michelle  Jim Jarmush  rater  RonJohnson  Dory
# 0      1                 1       NaN          1.0    NaN           2   2.0
# 1      1                 3       NaN          NaN    NaN           4   NaN
# 2      3                 3       NaN          NaN    NaN           4   NaN
# 3      3                 4       NaN          4.0    NaN           4   NaN
# 4      4                 4       NaN          NaN    4.0           5   5.0
# 5      5                 3       4.0          1.0    NaN           5   NaN
# 6      1                 3       NaN          1.0    NaN           2   NaN
# 7      3                 3       NaN          5.0    NaN           4   NaN
# 8      3                 3       3.0          3.0    NaN           5   NaN
# 9      5                 2       NaN          NaN    NaN           5   4.0
# 10     4                 5       5.0          5.0    NaN           5   4.0
# 11     3                 5       4.0          NaN    NaN           5   5.0
# 12     5                 5       4.0          NaN    NaN           4   NaN
# 13     5                 2       NaN          1.0    4.0           2   5.0
# 14     3                 5       4.0          NaN    NaN           3   5.0
# 15     4                 5       4.0          NaN    3.0           4   3.0
# 16     3                 1       NaN          NaN    NaN           4   NaN
# 17     3                 3       4.0          5.0    NaN           2   4.0
# 18     3                 5       3.0          NaN    NaN           4   3.0
# 19     3                 1       NaN          NaN    NaN           3   5.0
# 20     3                 2       NaN          NaN    NaN           1   NaN
# 21     3                 4       4.0          5.0    NaN           3   4.0
# 22     3                 4       3.0          NaN    NaN           3   5.0
# 23     5                 4       NaN          NaN    5.0           3   5.0
# 24     3                 3       NaN          NaN    NaN           3   NaN
# 25     5                 4       4.0          NaN    4.0           5   5.0
# 26     4                 5       3.0          4.0    NaN           3   4.0
# 27     3                 1       NaN          NaN    1.0           3   1.0
# 28     5                 4       3.0          NaN    NaN           3   3.0
# 29     3                 5       NaN          NaN    NaN           1   NaN
# 30     3                 5       NaN          NaN    NaN           5   NaN
# 31     3                 5       NaN          NaN    NaN           5   1.0
# 32     5                 2       NaN          2.0    4.0           2   NaN
# 33     3                 2       NaN          NaN    2.0           3   NaN
# 34     5                 1       NaN          NaN    NaN           3   3.0
# 35     4                 2       NaN          4.0    NaN           3   NaN
# 36     3                 4       NaN          4.0    NaN           4   NaN
# 37     3                 2       NaN          NaN    NaN           3   NaN
# 38     4                 4       5.0          NaN    NaN           4   NaN
# 39     5                 5       3.0          3.0    NaN           4   5.0
# 40     4                 5       4.0          3.0    5.0           4   NaN
# 41     4                 4       4.0          5.0    NaN           5   NaN
# 42     2                 2       3.0          4.0    NaN           3   NaN
# 43     2                 1       NaN          NaN    NaN           3   NaN
# 44     5                 4       4.0          NaN    NaN           5   4.0
# 45     2                 2       NaN          NaN    NaN           3   NaN
#
# [46 rows x 32 columns]

# %% [markdown]
# ** Task 1: User-based Recommendation with Cosine Metric**
#
# For a specified user, calculate ALL missing movie ratings using user-based recommendation with Cosine Metric.

# %%
def t1(name):
    sim_weights = {}
    missing_ratings = []
    
    for user in df.columns[1:]:
        if user == name:
            continue
        df_subset = df[[name,user]][df[name].notnull() & df[user].notnull()]
        dist = cosine(df_subset[name], df_subset[user])
        sim_weights[user] = 1.0 / (1.0 + dist)
    
    df_subset = df[name]
    for x in range(0, len(df)):
        movie_title = df['Alias'][x]
        user_rating = df_subset.iloc[x]
        
        if np.isnan(user_rating):
            predicted_rating = 0.0
            weights_sum = 0.0
            ratings = df.iloc[x][1:]
            
            for user in df.columns[1:]:
                if (user != name and not np.isnan(sim_weights[user]) and not np.isnan(ratings[user])):
                    predicted_rating += ratings[user] * sim_weights[user]
                    weights_sum += sim_weights[user]
            
            predicted_rating /= weights_sum
            missing_ratings.append((movie_title, predicted_rating))
                
    return missing_ratings

print(t1('BabyKangaroo'))
# Out:
# [('50 Shades of Grey', 1.800510039784056), ('Au Revoir Les Enfants', 2.677412888697481), ('Deadpool (2016)', 3.884560310821831), ("Don't Mess with the Zohan", 2.3252685926656045), ('Dr. Strange', 3.4874545533060894), ('Ex Machina', 3.295500789684209), ('Fast and Furious', 3.2643182745411243), ('Finding Dory', 3.797867126964514), ('Grownups', 2.6027977835524734), ("Harry Potter: The Sorcerer's Stone", 3.8440637198956455), ('Jurassic Park', 3.6299162284421977), ('Keanu', 2.7149176195697478), ('La La Land', 3.519753102584685), ('Lord of the Rings: Return of the King', 3.8882854882871607), ('Mr. Deeds', 3.110755481556487), ('Nacho Libre', 2.3646069694393863), ('Remember the Titans', 3.2135894977660335), ('Shrek', 4.113414168507833), ('Snakes on a Plane', 2.0812632781733402), ('Spiderman', 3.39690383570258), ('Star Wars: Episode IV', 3.704378124682928), ('Star Wars: The Return of the Jedi', 3.6867809290631763), ('Suicide Squad', 2.5957661280674174), ('Superbad', 3.3117330945104837), ('The Fifth Element', 3.066381137998995), ('The Fundamentals of Caring', 2.5692754757969065), ('The Room', 2.9957368864646106), ('Split (2016)', 2.9324233446691004), ('War Dogs', 2.572724262204735)]

# %% [markdown]
# ** Task 2: Item-based Recommendation with Cosine Metric**
#
# Repeat the task above by doing an item-based recommendation instead of a user based recommendation. To calculate a missing movie rating using item-based recommendation, you are supposed to find similarity between movies instead of users. In other words, you measure the similarity of the user's missing rating movie with movies that the user has rated in the past. Then compute a weighted average using similar movie weights and their ratings to find out the predicted rating. You need to predict ALL missing movie ratings for the user.

# %%
df_t = df.transpose()
df_t
# Out:
#                                                0         1   \
# Alias                           50 Shades of Grey  Airplane
# potatofaminewasaninsidejob                      1       NaN
# Thug Nugget                                   NaN       NaN
# Arjen_Robben_Is_Cool                          NaN       NaN
# Oh-Long Johnson                                 1         5
# BigD                                          NaN       NaN
# Starlord                                        1         3
# captainamerica                                  1       NaN
# BabyKangaroo                                  NaN         4
# Ryan                                            1         4
# poverty jones                                   2         4
# Hugh jackman                                    2         2
# Anastasia                                       5         1
# Christian Grey                                  5         3
# Steve Bannon                                  NaN       NaN
# Donald J. Trump                                 1         1
# Eternally Tempestuous                         NaN       NaN
# PGH Robin Hood                                NaN       NaN
# Craig sucks                                   NaN         5
# Programmer? I hardly know her!                  1         4
# KappaPride                                      2         2
# Roger Ebert                                     1         4
# Garbage                                         3         5
# CleverAlias                                     3         3
# Kirito                                          1         5
# ryan                                            1         1
# Geek in the Pink                                1         3
# Michelle                                      NaN       NaN
# Jim Jarmush                                     1       NaN
# rater                                         NaN       NaN
# RonJohnson                                      2         4
# Dory                                            2       NaN
#
#                                                    2               3   \
# Alias                           Au Revoir Les Enfants  Blues Brothers
# potatofaminewasaninsidejob                        NaN             NaN
# Thug Nugget                                       NaN             NaN
# Arjen_Robben_Is_Cool                              NaN             NaN
# Oh-Long Johnson                                     2               4
# BigD                                              NaN             NaN
# Starlord                                          NaN             NaN
# captainamerica                                    NaN             NaN
# BabyKangaroo                                      NaN               2
# Ryan                                                3               3
# poverty jones                                       3               3
# Hugh jackman                                        3               3
# Anastasia                                           1               1
# Christian Grey                                      3               3
# Steve Bannon                                      NaN               3
# Donald J. Trump                                     1               1
# Eternally Tempestuous                             NaN             NaN
# PGH Robin Hood                                    NaN             NaN
# Craig sucks                                       NaN               4
# Programmer? I hardly know her!                      3               4
# KappaPride                                          3               5
# Roger Ebert                                         2               4
# Garbage                                             3               5
# CleverAlias                                         3               3
# Kirito                                            NaN               4
# ryan                                                3               3
# Geek in the Pink                                    3               4
# Michelle                                          NaN             NaN
# Jim Jarmush                                       NaN               4
# rater                                             NaN             NaN
# RonJohnson                                          4               4
# Dory                                              NaN             NaN
#
#                                         4                5   \
# Alias                           Dark Night  Deadpool (2016)
# potatofaminewasaninsidejob             NaN                4
# Thug Nugget                              3                4
# Arjen_Robben_Is_Cool                   NaN              NaN
# Oh-Long Johnson                          5                5
# BigD                                     5              NaN
# Starlord                                 5                2
# captainamerica                         NaN                5
# BabyKangaroo                             5              NaN
# Ryan                                     5                4
# poverty jones                            5                5
# Hugh jackman                             4                5
# Anastasia                                1                1
# Christian Grey                           3                5
# Steve Bannon                           NaN                5
# Donald J. Trump                          1                1
# Eternally Tempestuous                  NaN              NaN
# PGH Robin Hood                         NaN              NaN
# Craig sucks                              5                2
# Programmer? I hardly know her!           5                5
# KappaPride                               3                4
# Roger Ebert                              5                5
# Garbage                                  4                5
# CleverAlias                              3                4
# Kirito                                   4                4
# ryan                                     4                5
# Geek in the Pink                         4                3
# Michelle                               NaN                4
# Jim Jarmush                            NaN                1
# rater                                    4              NaN
# RonJohnson                               5                5
# Dory                                     5              NaN
#
#                                                        6            7   \
# Alias                           Don't Mess with the Zohan  Dr. Strange
# potatofaminewasaninsidejob                            NaN            4
# Thug Nugget                                           NaN          NaN
# Arjen_Robben_Is_Cool                                    3          NaN
# Oh-Long Johnson                                         5            3
# BigD                                                  NaN          NaN
# Starlord                                                2            4
# captainamerica                                        NaN            5
# BabyKangaroo                                          NaN          NaN
# Ryan                                                    2            4
# poverty jones                                           2            3
# Hugh jackman                                            3            5
# Anastasia                                               1            1
# Christian Grey                                          3            5
# Steve Bannon                                          NaN            3
# Donald J. Trump                                         1            1
# Eternally Tempestuous                                 NaN          NaN
# PGH Robin Hood                                        NaN          NaN
# Craig sucks                                           NaN          NaN
# Programmer? I hardly know her!                          4            2
# KappaPride                                              2            4
# Roger Ebert                                             2            2
# Garbage                                                 1            3
# CleverAlias                                             3            5
# Kirito                                                  3            4
# ryan                                                    1            3
# Geek in the Pink                                        3            3
# Michelle                                              NaN          NaN
# Jim Jarmush                                             1            5
# rater                                                 NaN          NaN
# RonJohnson                                              2            4
# Dory                                                  NaN          NaN
#
#                                         8                 9   ...  \
# Alias                           Ex Machina  Fast and Furious  ...
# potatofaminewasaninsidejob               4               NaN  ...
# Thug Nugget                            NaN               NaN  ...
# Arjen_Robben_Is_Cool                   NaN               NaN  ...
# Oh-Long Johnson                          2                 1  ...
# BigD                                   NaN                 4  ...
# Starlord                                 4                 1  ...
# captainamerica                         NaN                 3  ...
# BabyKangaroo                           NaN               NaN  ...
# Ryan                                     5                 2  ...
# poverty jones                            4                 4  ...
# Hugh jackman                             3                 5  ...
# Anastasia                                1                 1  ...
# Christian Grey                           3                 5  ...
# Steve Bannon                             4                 3  ...
# Donald J. Trump                          1                 1  ...
# Eternally Tempestuous                  NaN               NaN  ...
# PGH Robin Hood                         NaN                 3  ...
# Craig sucks                            NaN                 2  ...
# Programmer? I hardly know her!           2                 5  ...
# KappaPride                               4                 4  ...
# Roger Ebert                              4                 3  ...
# Garbage                                  4                 3  ...
# CleverAlias                              3                 5  ...
# Kirito                                   4                 4  ...
# ryan                                     3                 5  ...
# Geek in the Pink                         3                 2  ...
# Michelle                                 3               NaN  ...
# Jim Jarmush                              3               NaN  ...
# rater                                  NaN               NaN  ...
# RonJohnson                               5                 5  ...
# Dory                                   NaN                 4  ...
#
#                                                36                          37  \
# Alias                           The Fifth Element  The Fundamentals of Caring
# potatofaminewasaninsidejob                    NaN                         NaN
# Thug Nugget                                   NaN                         NaN
# Arjen_Robben_Is_Cool                          NaN                         NaN
# Oh-Long Johnson                               NaN                         NaN
# BigD                                          NaN                         NaN
# Starlord                                        5                         NaN
# captainamerica                                NaN                         NaN
# BabyKangaroo                                  NaN                         NaN
# Ryan                                            3                           4
# poverty jones                                   2                           1
# Hugh jackman                                    3                           3
# Anastasia                                       1                           3
# Christian Grey                                  3                           3
# Steve Bannon                                  NaN                         NaN
# Donald J. Trump                                 1                           1
# Eternally Tempestuous                           3                         NaN
# PGH Robin Hood                                  3                         NaN
# Craig sucks                                     4                         NaN
# Programmer? I hardly know her!                  2                           2
# KappaPride                                      4                           3
# Roger Ebert                                     2                           2
# Garbage                                         4                           1
# CleverAlias                                     3                           5
# Kirito                                        NaN                         NaN
# ryan                                            3                           3
# Geek in the Pink                                4                           2
# Michelle                                      NaN                         NaN
# Jim Jarmush                                     4                         NaN
# rater                                         NaN                         NaN
# RonJohnson                                      4                           3
# Dory                                          NaN                         NaN
#
#                                            38                  39  \
# Alias                           The Godfather  The Imitation Game
# potatofaminewasaninsidejob                NaN                   4
# Thug Nugget                                 1                 NaN
# Arjen_Robben_Is_Cool                      NaN                 NaN
# Oh-Long Johnson                             5                   4
# BigD                                      NaN                   5
# Starlord                                  NaN                   5
# captainamerica                              4                   5
# BabyKangaroo                                5                   3
# Ryan                                        5                   5
# poverty jones                               4                   3
# Hugh jackman                                5                   1
# Anastasia                                   3                   3
# Christian Grey                              5                   3
# Steve Bannon                              NaN                   4
# Donald J. Trump                             2                   1
# Eternally Tempestuous                     NaN                 NaN
# PGH Robin Hood                              4                 NaN
# Craig sucks                                 4                 NaN
# Programmer? I hardly know her!              2                   5
# KappaPride                                  5                   3
# Roger Ebert                                 2                   5
# Garbage                                     5                   5
# CleverAlias                                 3                   3
# Kirito                                      4                 NaN
# ryan                                        4                   5
# Geek in the Pink                            4                   5
# Michelle                                    5                   3
# Jim Jarmush                               NaN                   3
# rater                                     NaN                 NaN
# RonJohnson                                  4                   4
# Dory                                      NaN                   5
#
#                                          40          41        42  \
# Alias                           The Martian  The Matrix  The Room
# potatofaminewasaninsidejob                4           5         3
# Thug Nugget                               4           4       NaN
# Arjen_Robben_Is_Cool                    NaN           5       NaN
# Oh-Long Johnson                           4           4         1
# BigD                                      4         NaN       NaN
# Starlord                                  4           5       NaN
# captainamerica                          NaN         NaN       NaN
# BabyKangaroo                              4           3       NaN
# Ryan                                      4           5         3
# poverty jones                             4           4         4
# Hugh jackman                              2           5         2
# Anastasia                                 3           5         1
# Christian Grey                            4           5         3
# Steve Bannon                              4         NaN       NaN
# Donald J. Trump                           1           1         1
# Eternally Tempestuous                   NaN         NaN       NaN
# PGH Robin Hood                          NaN           4       NaN
# Craig sucks                             NaN           4       NaN
# Programmer? I hardly know her!            5           5         5
# KappaPride                                3           5         4
# Roger Ebert                               5           5         5
# Garbage                                   4           4         5
# CleverAlias                               5           5         5
# Kirito                                    4           4         1
# ryan                                      4           4         2
# Geek in the Pink                          5           4         2
# Michelle                                  4           4         3
# Jim Jarmush                               3           5         4
# rater                                     5         NaN       NaN
# RonJohnson                                4           5         3
# Dory                                    NaN         NaN       NaN
#
#                                           43         44        45
# Alias                           Split (2016)  Toy Story  War Dogs
# potatofaminewasaninsidejob               NaN        NaN       NaN
# Thug Nugget                              NaN        NaN       NaN
# Arjen_Robben_Is_Cool                     NaN        NaN       NaN
# Oh-Long Johnson                          NaN        NaN       NaN
# BigD                                     NaN          5       NaN
# Starlord                                 NaN          4         3
# captainamerica                           NaN          4       NaN
# BabyKangaroo                             NaN          5       NaN
# Ryan                                       3          5         3
# poverty jones                              2          5         4
# Hugh jackman                               4          5         2
# Anastasia                                  5          5         1
# Christian Grey                             2          5         1
# Steve Bannon                               4          4         3
# Donald J. Trump                            1          1         1
# Eternally Tempestuous                    NaN          3       NaN
# PGH Robin Hood                           NaN        NaN       NaN
# Craig sucks                              NaN          5       NaN
# Programmer? I hardly know her!             5          5         4
# KappaPride                                 3          5         4
# Roger Ebert                                2          3         3
# Garbage                                    4          5         3
# CleverAlias                                3          5         2
# Kirito                                   NaN          4       NaN
# ryan                                       2          5         2
# Geek in the Pink                           1          4         2
# Michelle                                 NaN          4       NaN
# Jim Jarmush                              NaN        NaN       NaN
# rater                                    NaN        NaN       NaN
# RonJohnson                                 3          5         3
# Dory                                     NaN          4       NaN
#
# [32 rows x 46 columns]

# %%
name = 'BabyKangaroo' # not necessary to have in task.py
unrated_movies = {}
sim_weights = {}
predicted_ratings = []

for x in range(0, len(df)):
    if np.isnan(df[name][x]):
        unrated_movies[x] = df['Alias'][x]

print(unrated_movies)

df_t = df.transpose()

for x in unrated_movies:
    movie_title = unrated_movies[x]
    
    for y in range(0, len(df)):
        movie = df['Alias'][y]
        if movie_title == movie:
            continue
        
        df_subset = df_t[[x,y]][df_t[x].notnull() & df_t[y].notnull()]
        dist = cosine(df_subset[x][1:].astype(float), df_subset[y][1:].astype(float))
        sim_weights[movie] = 1.0 / (1.0 + dist)
    
    df_subset = df[['Alias', name]]
    predicted_rating = 0.0
    weights_sum = 0.0
    
    for y in range(0, len(df)):
        title = df['Alias'][y]
        user_rating = df[name][y]
        
        if not np.isnan(user_rating):
            predicted_rating += user_rating * sim_weights[title]
            weights_sum += sim_weights[title]
    
    predicted_rating /= weights_sum
    predicted_ratings.append((movie_title, predicted_rating))

print(predicted_ratings)
# Out:
# {0: '50 Shades of Grey', 2: 'Au Revoir Les Enfants', 5: 'Deadpool (2016)', 6: "Don't Mess with the Zohan", 7: 'Dr. Strange', 8: 'Ex Machina', 9: 'Fast and Furious', 11: 'Finding Dory', 13: 'Grownups', 14: "Harry Potter: The Sorcerer's Stone", 15: 'Jurassic Park', 16: 'Keanu', 17: 'La La Land', 18: 'Lord of the Rings: Return of the King', 19: 'Mr. Deeds', 20: 'Nacho Libre', 23: 'Remember the Titans', 26: 'Shrek', 27: 'Snakes on a Plane', 28: 'Spiderman', 30: 'Star Wars: Episode IV', 31: 'Star Wars: The Return of the Jedi', 33: 'Suicide Squad', 34: 'Superbad', 36: 'The Fifth Element', 37: 'The Fundamentals of Caring', 42: 'The Room', 43: 'Split (2016)', 45: 'War Dogs'}
# [('50 Shades of Grey', 3.840697103825371), ('Au Revoir Les Enfants', 3.837148837940922), ('Deadpool (2016)', 3.8361975395092305), ("Don't Mess with the Zohan", 3.845472550871293), ('Dr. Strange', 3.843828651475236), ('Ex Machina', 3.8445823636457663), ('Fast and Furious', 3.828684359043295), ('Finding Dory', 3.833104140055631), ('Grownups', 3.825115016071228), ("Harry Potter: The Sorcerer's Stone", 3.8341887055894737), ('Jurassic Park', 3.829041119096047), ('Keanu', 3.844282503671195), ('La La Land', 3.849729461098438), ('Lord of the Rings: Return of the King', 3.8314877996133756), ('Mr. Deeds', 3.8298690329409193), ('Nacho Libre', 3.844690392533152), ('Remember the Titans', 3.83149990925786), ('Shrek', 3.8452569652934327), ('Snakes on a Plane', 3.829452714731817), ('Spiderman', 3.818171681222897), ('Star Wars: Episode IV', 3.82790976449509), ('Star Wars: The Return of the Jedi', 3.8290712680691543), ('Suicide Squad', 3.8388755783067547), ('Superbad', 3.854395357416007), ('The Fifth Element', 3.8458520658067537), ('The Fundamentals of Caring', 3.8374100623337157), ('The Room', 3.8204482082959754), ('Split (2016)', 3.847902715551797), ('War Dogs', 3.8474572409115924)]

# %% [markdown]
# ** Task 3: User-based Recommendation with Cosine Metric**
#
# Repeat Task 1 while computing the weighted average using just top 10 most similar users instead of all users.

# %%
def t3(name):
    sim_weights = {}
    missing_ratings = []
    
    for user in df.columns[1:]:
        if user == name:
            continue
        df_subset = df[[name,user]][df[name].notnull() & df[user].notnull()]
        dist = cosine(df_subset[name], df_subset[user])
        sim_weights[user] = 1.0 / (1.0 + dist)
    
    sim_weights = {k: v for k, v in sorted(sim_weights.items(), key=lambda item: item[1], reverse=True)[:10]}
    
    df_subset = df[name]
    for x in range(0, len(df)):
        movie_title = df['Alias'][x]
        user_rating = df_subset.iloc[x]
        
        if np.isnan(user_rating):
            predicted_rating = 0.0
            weights_sum = 0.0
            ratings = df.iloc[x][1:]
            
            for user in df.columns[1:]:
                if (user != name and user in sim_weights and not np.isnan(sim_weights[user]) and not np.isnan(ratings[user])):
                    predicted_rating += ratings[user] * sim_weights[user]
                    weights_sum += sim_weights[user]
            
            predicted_rating /= weights_sum
            missing_ratings.append((movie_title, predicted_rating))
                
    return missing_ratings

print(t3('BabyKangaroo'))
# Out:
# [('50 Shades of Grey', 1.2501062977225976), ('Au Revoir Les Enfants', 2.499979499698017), ('Deadpool (2016)', 3.6715087825874733), ("Don't Mess with the Zohan", 3.0003808055650913), ('Dr. Strange', 3.499050502383946), ('Ex Machina', 3.598541193625111), ('Fast and Furious', 2.43305340976135), ('Finding Dory', 3.7530297156456833), ('Grownups', 2.5712769115930887), ("Harry Potter: The Sorcerer's Stone", 3.751014292593285), ('Jurassic Park', 3.447578069750026), ('Keanu', 2.3304483131845752), ('La La Land', 3.80217068036191), ('Lord of the Rings: Return of the King', 4.124140887522079), ('Mr. Deeds', 3.165723776145156), ('Nacho Libre', 2.99787714677672), ('Remember the Titans', 3.4998598496048094), ('Shrek', 3.871824257347736), ('Snakes on a Plane', 1.3758214108843625), ('Spiderman', 3.1153416120632498), ('Star Wars: Episode IV', 4.201510804793711), ('Star Wars: The Return of the Jedi', 3.8569293788600487), ('Suicide Squad', 1.857633145720359), ('Superbad', 3.714544137074008), ('The Fifth Element', 3.7484123354652015), ('The Fundamentals of Caring', 4.0), ('The Room', 2.336768223245549), ('Split (2016)', 3.501631320278993), ('War Dogs', 3.0000000000000004)]
